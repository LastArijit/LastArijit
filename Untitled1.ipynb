# %% [markdown]
# <a href="https://colab.research.google.com/github/LastArijit/LastArijit/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install datasets

# %%
from datasets import load_dataset

# %%
datasets = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = datasets['train'].to_pandas()
#Basically saying that get the training data from the datasets and using the method to_pandas() - I am organising it into a table.

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
type(df) #Looks nerdy
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.shape
# Out:
# (785741, 17)

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df_da = df[df['job_title_short'] == 'Data Analyst']

# %%
df_da.shape

# %%
df['job_title_short']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/1028982620.py in <cell line: 0>()
# ----> 1 df['job_title_short']
#
# NameError: name 'df' is not defined

# %%
df_high_salary = df[(df['job_title_short'] == 'Data Analyst') & (df['salary_year_avg'] > 100000)]

# %%
df_high_salary
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
df.groupby('job_title_short')['salary_year_avg'].mean().sort_values(ascending=False)
# Out:
# job_title_short
# Senior Data Scientist        154206.292996
# Senior Data Engineer         145840.611624
# Data Scientist               135988.837171
# Data Engineer                130125.604250
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Software Engineer            113393.760054
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Business Analyst              91082.612833
# Name: salary_year_avg, dtype: float64

# %%
df[df['job_title_short'] == 'Data Analyst']['job_country'].value_counts().head(10)
# Out:
# job_country
# United States     67816
# France            13803
# United Kingdom    10482
# Germany            7131
# Singapore          6632
# India              6121
# Spain              5177
# Philippines        4766
# Italy              4543
# Netherlands        4123
# Name: count, dtype: int64

# %%
df.groupby('job_country')['salary_year_avg'].mean().sort_values(ascending=False).head(10)
# Out:
# job_country
# Belarus                     400000.000000
# Russia                      292500.000000
# Bahamas                     201511.619048
# Dominican Republic          157500.000000
# Northern Mariana Islands    155485.500000
# Côte d'Ivoire               147500.000000
# Namibia                     140857.142857
# Sudan                       134051.577942
# United States               126134.487958
# Chile                       124918.454545
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_country')['salary_year_avg'].agg(['count','mean']).sort_values('mean', ascending=False).head(10)
# Out:
#                           count           mean
# job_country
# Belarus                       1  400000.000000
# Russia                        4  292500.000000
# Bahamas                      21  201511.619048
# Dominican Republic            1  157500.000000
# Northern Mariana Islands      1  155485.500000
# Côte d'Ivoire                 1  147500.000000
# Namibia                       7  140857.142857
# Sudan                      1623  134051.577942
# United States             15766  126134.487958
# Chile                        11  124918.454545

# %%
country_salary = df.groupby('job_country')['salary_year_avg'].agg(['count','mean'])

# %%
country_salary[country_salary['count'] >= 100]
# Out:
#                 count           mean
# job_country
# Canada            463  123121.533477
# France            237  104511.658228
# Germany           257  115800.564202
# India             582  113602.182131
# Israel            103  111304.063107
# Mexico            111  114950.238739
# Poland            200  106946.167500
# Portugal          131  116437.671756
# Spain             144  107357.187500
# Sudan            1623  134051.577942
# United Kingdom    287  109951.151568
# United States   15766  126134.487958

# %%
country_salary[country_salary['count'] >= 100].sort_values('mean', ascending=False)
# Out:
#                 count           mean
# job_country
# Sudan            1623  134051.577942
# United States   15766  126134.487958
# Canada            463  123121.533477
# Portugal          131  116437.671756
# Germany           257  115800.564202
# Mexico            111  114950.238739
# India             582  113602.182131
# Israel            103  111304.063107
# United Kingdom    287  109951.151568
# Spain             144  107357.187500
# Poland            200  106946.167500
# France            237  104511.658228

# %%
country_salary = df.groupby('job_country')['salary_year_avg'].agg(['count','mean'])

country_salary[country_salary['count'] >= 100].sort_values('mean', ascending=False).head(10)
# Out:
#                 count           mean
# job_country
# Sudan            1623  134051.577942
# United States   15766  126134.487958
# Canada            463  123121.533477
# Portugal          131  116437.671756
# Germany           257  115800.564202
# Mexico            111  114950.238739
# India             582  113602.182131
# Israel            103  111304.063107
# United Kingdom    287  109951.151568
# Spain             144  107357.187500

# %%
df[df['job_country'] == 'Sudan'][['job_title_short','salary_year_avg','company_name']].head(20)
# Out:
#            job_title_short  salary_year_avg  \
# 4            Data Engineer              NaN
# 62          Data Scientist              NaN
# 70   Senior Data Scientist              NaN
# 77           Data Engineer         140000.0
# 86           Data Engineer              NaN
# 96           Data Engineer              NaN
# 105         Data Scientist              NaN
# 113          Data Engineer              NaN
# 156          Data Engineer              NaN
# 182          Data Engineer              NaN
# 195  Senior Data Scientist              NaN
# 207          Data Engineer              NaN
# 247          Data Engineer              NaN
# 248          Data Engineer              NaN
# 254         Data Scientist              NaN
# 278          Data Engineer              NaN
# 279          Data Engineer              NaN
# 281         Data Scientist              NaN
# 296         Data Scientist              NaN
# 318           Data Analyst              NaN
#
# ...

# %%
df.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False)
# Out:
# job_title_short
# Senior Data Scientist        155500.0
# Senior Data Engineer         147500.0
# Data Scientist               127500.0
# Data Engineer                125000.0
# Senior Data Analyst          111175.0
# Machine Learning Engineer    106415.0
# Software Engineer             99150.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Business Analyst              85000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# # New Section
